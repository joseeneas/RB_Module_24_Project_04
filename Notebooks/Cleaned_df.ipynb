# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results_df = pd.read_csv("../Resources/1950-2013/results.csv")
status_df = pd.read_csv("../Resources/1950-2013/status.csv")
driver_df = pd.read_csv("../Resources/1950-2013/drivers.csv",encoding='latin1')

# %%
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps     time  milliseconds  \
# 0            1              1    10.0    58  34:50.6     5690616.0
# 1            2              2     8.0    58    5.478     5696094.0
# 2            3              3     6.0    58    8.163     5698779.0
# 3            4              4     5.0    58   17.181     5707797.0
# 4            5              5     4.0    58   18.014     5708630.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0        39.0   2.0        01:27.5           218.3         1
# ...

# %%
status_df.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
merged_df = results_df.merge(status_df, on='statusId', how='left')

# %%
merged_df.head(20)
# Out:
#     resultId  raceId  driverId  constructorId  number  grid  position  \
# 0          1      18         1              1    22.0     1       1.0
# 1          2      18         2              2     3.0     5       2.0
# 2          3      18         3              3     7.0     7       3.0
# 3          4      18         4              4     5.0    11       4.0
# 4          5      18         5              1    23.0     3       5.0
# 5          6      18         6              3     8.0    13       6.0
# 6          7      18         7              5    14.0    17       7.0
# 7          8      18         8              6     1.0    15       8.0
# 8          9      18         9              2     4.0     2       NaN
# 9         10      18        10              7    12.0    18       NaN
# 10        11      18        11              8    18.0    19       NaN
# 11        12      18        12              4     6.0    20       NaN
# ...

# %%
updated_results_df = merged_df.drop(columns=["statusId"])
updated_results_df = updated_results_df.dropna()
updated_results_df.head(50)
# Out:
#      resultId  raceId  driverId  constructorId  number  grid  position  \
# 0           1      18         1              1    22.0     1       1.0
# 1           2      18         2              2     3.0     5       2.0
# 2           3      18         3              3     7.0     7       3.0
# 3           4      18         4              4     5.0    11       4.0
# 4           5      18         5              1    23.0     3       5.0
# 22         23      19         8              6     1.0     2       1.0
# 23         24      19         9              2     4.0     4       2.0
# 24         25      19         5              1    23.0     8       3.0
# 25         26      19        15              7    11.0     3       4.0
# 26         27      19         1              1    22.0     9       5.0
# 27         28      19         2              2     3.0     5       6.0
# 28         29      19        17              9    10.0     6       7.0
# ...

# %%
#updated_results_df.to_csv("../Resources/1950-2013/merged_results_and_status.csv")

# %%
# Reading races csv and circuits csv
races_df = pd.read_csv("../Resources/1950-2013/races.csv")
circuits_df = pd.read_csv("../Resources/1950-2013/circuits.csv",encoding='latin1')

# %%
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
#dropped_url_circuits_df = circuits_df.drop(columns=["url"])
circuits_df.head(20)
# Out:
#     circuitId      circuitRef                            name      location  \
# 0           1     albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1           2          sepang    Sepang International Circuit  Kuala Lumpur
# 2           3         bahrain   Bahrain International Circuit        Sakhir
# 3           4       catalunya  Circuit de Barcelona-Catalunya     MontmelÌ_
# 4           5        istanbul                   Istanbul Park      Istanbul
# 5           6          monaco               Circuit de Monaco   Monte-Carlo
# 6           7      villeneuve       Circuit Gilles Villeneuve      Montreal
# 7           8     magny_cours   Circuit de Nevers Magny-Cours   Magny Cours
# 8           9     silverstone             Silverstone Circuit   Silverstone
# 9          10  hockenheimring                  Hockenheimring    Hockenheim
# 10         11     hungaroring                     Hungaroring      Budapest
# ...

# %%
updated_results_df= updated_results_df.merge(races_df[["raceId","circuitId"]], on="raceId", how='left')

# %%
updated_results_df.head(10)
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
# 5        23      19         8              6     1.0     2       1.0
# 6        24      19         9              2     4.0     4       2.0
# 7        25      19         5              1    23.0     8       3.0
# 8        26      19        15              7    11.0     3       4.0
# 9        27      19         1              1    22.0     9       5.0
#
#   positionText  positionOrder  points  ...     time milliseconds  fastestLap  \
# 0            1              1    10.0  ...  34:50.6    5690616.0        39.0
# ...

# %%
updated_results_df = updated_results_df.merge(circuits_df[["circuitId","name","country"]], on="circuitId", how='left')

# %%
updated_results_df.head(10)
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
# 5        23      19         8              6     1.0     2       1.0
# 6        24      19         9              2     4.0     4       2.0
# 7        25      19         5              1    23.0     8       3.0
# 8        26      19        15              7    11.0     3       4.0
# 9        27      19         1              1    22.0     9       5.0
#
#   positionText  positionOrder  points  ...     time milliseconds  fastestLap  \
# 0            1              1    10.0  ...  34:50.6    5690616.0        39.0
# ...

# %%
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
# Sort races_df by year
sorted_races_df = races_df.sort_values(by='year')

# Display the first few rows of the sorted DataFrame
sorted_races_df.tail(30)
# Out:
#      raceId  year  round  circuitId                      name        date  \
# 963     976  2017      8         73     Azerbaijan Grand Prix  2017-06-25
# 962     975  2017      7          7       Canadian Grand Prix  2017-06-11
# 961     974  2017      6          6         Monaco Grand Prix  2017-05-28
# 960     973  2017      5          4        Spanish Grand Prix  2017-05-14
# 959     972  2017      4         71        Russian Grand Prix  2017-04-30
# 958     971  2017      3          3        Bahrain Grand Prix  2017-04-16
# 957     970  2017      2         17        Chinese Grand Prix  2017-04-09
# 956     969  2017      1          1     Australian Grand Prix  2017-03-26
# 965     978  2017     10          9        British Grand Prix  2017-07-16
# 988    1001  2018     13         13        Belgian Grand Prix  2018-08-26
# 989    1002  2018     14         14        Italian Grand Prix  2018-09-02
# 990    1003  2018     15         15      Singapore Grand Prix  2018-09-16
# ...

# %%
sorted_races_df.to_csv("../Resources/1950-2013/races_sorted_by_year.csv")

# %%
dropped_url_and_round_df =sorted_races_df.drop(columns=["url","round"])

# %%
dropped_url_and_round_df.head()
# Out:
#      raceId  year  circuitId                name        date time
# 838     839  1950         14  Italian Grand Prix  1950-09-03  NaN
# 837     838  1950         55   French Grand Prix  1950-07-02  NaN
# 836     837  1950         13  Belgian Grand Prix  1950-06-18  NaN
# 835     836  1950         66    Swiss Grand Prix  1950-06-04  NaN
# 834     835  1950         19    Indianapolis 500  1950-05-30  NaN

# %%
dropped_url_and_round_df.to_csv("../Resources/1950-2013/races_sorted_by_year.csv")

# %%
from unidecode import unidecode

# Read the CSV file into a DataFrame
df = circuits_df

# Assuming 'name' is the column with accent names
df['name'] = df['name'].apply(unidecode)
df['location'] = df['location'].apply(unidecode)
def remove_accents(text):
    return unidecode(text)
df['name'] = df['name'].apply(remove_accents)
df['location'] = df['location'].apply(remove_accents)

# %%
df.head(50)
# Out:
#     circuitId      circuitRef                                    name  \
# 0           1     albert_park          Albert Park Grand Prix Circuit
# 1           2          sepang            Sepang International Circuit
# 2           3         bahrain           Bahrain International Circuit
# 3           4       catalunya          Circuit de Barcelona-Catalunya
# 4           5        istanbul                           Istanbul Park
# 5           6          monaco                       Circuit de Monaco
# 6           7      villeneuve               Circuit Gilles Villeneuve
# 7           8     magny_cours           Circuit de Nevers Magny-Cours
# 8           9     silverstone                     Silverstone Circuit
# 9          10  hockenheimring                          Hockenheimring
# 10         11     hungaroring                             Hungaroring
# 11         12        valencia                 Valencia Street Circuit
# ...

# %%
driver_df.head()
# Out:
#    driverId   driverRef  number code  forename     surname         dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton  07/01/1985
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld  10/05/1977
# 2         3     rosberg     6.0  ROS      Nico     Rosberg  27/06/1985
# 3         4      alonso    14.0  ALO  Fernando      Alonso  29/07/1981
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  19/10/1981
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
dropped_num_and_url = driver_df.drop(columns=["url","number"])

# %%
dropped_num_and_url.head()
# Out:
#    driverId   driverRef code  forename     surname         dob nationality
# 0         1    hamilton  HAM     Lewis    Hamilton  07/01/1985     British
# 1         2    heidfeld  HEI      Nick    Heidfeld  10/05/1977      German
# 2         3     rosberg  ROS      Nico     Rosberg  27/06/1985      German
# 3         4      alonso  ALO  Fernando      Alonso  29/07/1981     Spanish
# 4         5  kovalainen  KOV    Heikki  Kovalainen  19/10/1981     Finnish

# %%
clean_drivers_df = dropped_num_and_url

def remove_accents(text):
    return unidecode(text)
clean_drivers_df['surname'] = clean_drivers_df['surname'].apply(unidecode)
clean_drivers_df['forename'] = clean_drivers_df['forename'].apply(unidecode)
clean_drivers_df.to_csv("../Resources/1950-2013/clean_drivers.csv")

# %%
clean_drivers_df.head(30)
# Out:
#     driverId           driverRef code      forename      surname         dob  \
# 0          1            hamilton  HAM         Lewis     Hamilton  07/01/1985
# 1          2            heidfeld  HEI          Nick     Heidfeld  10/05/1977
# 2          3             rosberg  ROS          Nico      Rosberg  27/06/1985
# 3          4              alonso  ALO      Fernando       Alonso  29/07/1981
# 4          5          kovalainen  KOV        Heikki   Kovalainen  19/10/1981
# 5          6            nakajima  NAK        Kazuki     Nakajima  11/01/1985
# 6          7            bourdais  BOU  SI(c)bastien     Bourdais  28/02/1979
# 7          8           raikkonen  RAI          Kimi  RI_ikkI|nen  17/10/1979
# 8          9              kubica  KUB        Robert       Kubica  07/12/1984
# 9         10               glock  GLO          Timo        Glock  18/03/1982
# 10        11                sato  SAT        Takuma         Sato  28/01/1977
# ...

# %%
updated_results_df.to_csv("../Resources/1950-2013/updated_results.csv")

# %%
updated_results_df = updated_results_df.merge(races_df[["raceId","year"]], on="raceId", how='left')

# %%
updated_results_df.to_csv("../Resources/1950-2013/updated_results.csv")
